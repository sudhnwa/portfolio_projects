# %% [markdown]
# The data set contains sales data from 2011 to 2015, by analyzing data, attempt to answer the following questions has been made.
#
# -What is the overall sales trend?
#
# -Which are the Top 10 products by sales?
#
# -Which are the Most Selling Products?
#
# -Which is the most preferred Ship Mode?
#
# -Which are the Most Profitable Category and Sub-Category?

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import plotly.express as px

pd.set_option('display.max_column', 22)

# %%
sales_df = pd.read_excel('superstore_sales.xlsx')
sales_df.shape
# Out:
# (51290, 21)

# %%
sales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51290 entries, 0 to 51289
# Data columns (total 21 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   order_id        51290 non-null  object
#  1   order_date      51290 non-null  datetime64[ns]
#  2   ship_date       51290 non-null  datetime64[ns]
#  3   ship_mode       51290 non-null  object
#  4   customer_name   51290 non-null  object
#  5   segment         51290 non-null  object
#  6   state           51290 non-null  object
#  7   country         51290 non-null  object
#  8   market          51290 non-null  object
#  9   region          51290 non-null  object
#  10  product_id      51290 non-null  object
#  11  category        51290 non-null  object
#  12  sub_category    51290 non-null  object
#  13  product_name    51290 non-null  object
#  14  sales           51290 non-null  float64
#  15  quantity        51290 non-null  int64
# ...

# %%
sales_df.head(10)
# Out:
#           order_id order_date  ship_date       ship_mode     customer_name  \
# 0     AG-2011-2040 2011-01-01 2011-01-06  Standard Class   Toby Braunhardt
# 1    IN-2011-47883 2011-01-01 2011-01-08  Standard Class       Joseph Holt
# 2     HU-2011-1220 2011-01-01 2011-01-05    Second Class     Annie Thurman
# 3  IT-2011-3647632 2011-01-01 2011-01-05    Second Class      Eugene Moren
# 4    IN-2011-47883 2011-01-01 2011-01-08  Standard Class       Joseph Holt
# 5    IN-2011-47883 2011-01-01 2011-01-08  Standard Class       Joseph Holt
# 6     CA-2011-1510 2011-01-02 2011-01-06  Standard Class   Magdelene Morse
# 7    IN-2011-79397 2011-01-03 2011-01-03        Same Day       Kean Nguyen
# 8    ID-2011-80230 2011-01-03 2011-01-09  Standard Class      Ken Lonsdale
# 9     IZ-2011-4680 2011-01-03 2011-01-07  Standard Class  Lindsay Williams
#
#        segment            state      country  market   region  \
# 0     Consumer      Constantine      Algeria  Africa   Africa
# ...

# %%
sales_df.tail()
# Out:
#              order_id order_date  ship_date       ship_mode     customer_name  \
# 51285  CA-2014-115427 2014-12-31 2015-01-04  Standard Class        Erica Bern
# 51286    MO-2014-2560 2014-12-31 2015-01-05  Standard Class         Liz Preis
# 51287  MX-2014-110527 2014-12-31 2015-01-02    Second Class  Charlotte Melton
# 51288  MX-2014-114783 2014-12-31 2015-01-06  Standard Class     Tamara Dahlen
# 51289  CA-2014-156720 2014-12-31 2015-01-04  Standard Class     Jill Matthias
#
#          segment             state        country  market   region  \
# 51285  Corporate        California  United States      US     West
# 51286   Consumer  Souss-Massa-Draâ        Morocco  Africa   Africa
# 51287   Consumer           Managua      Nicaragua   LATAM  Central
# 51288   Consumer         Chihuahua         Mexico   LATAM    North
# 51289   Consumer          Colorado  United States      US     West
#
#              product_id         category sub_category  \
# ...

# %%
sales_df.isna().sum()
# Out:
# order_id          0
# order_date        0
# ship_date         0
# ship_mode         0
# customer_name     0
# segment           0
# state             0
# country           0
# market            0
# region            0
# product_id        0
# category          0
# sub_category      0
# product_name      0
# sales             0
# quantity          0
# discount          0
# profit            0
# shipping_cost     0
# order_priority    0
# year              0
# dtype: int64

# %%
sales_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# The data niether contains null values nor duplicate values, hence we can now carry out our exploratory data analysis.

# %% [markdown]
# __

# %% [markdown]
# - <h4>What is overall sales trend ?</h4>

# %%
graph = px.line(data_frame=sales_df, x=sales_df['order_date'], y=sales_df['sales'])
graph.show(renderer = 'iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_8.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# plotting for sales each day creates a line plot hard to comprehend and analyse, grouping on the month and year and and plotting the sum of of the sales that month might solve the issue.

# %%
sales_df['month_year'] = sales_df['order_date'].apply(lambda x : x.strftime('%Y-%m'))

# %%
sales_df['month_year']
# Out:
# 0        2011-01
# 1        2011-01
# 2        2011-01
# 3        2011-01
# 4        2011-01
#           ...
# 51285    2014-12
# 51286    2014-12
# 51287    2014-12
# 51288    2014-12
# 51289    2014-12
# Name: month_year, Length: 51290, dtype: object

# %%
monthly_sales_df = sales_df.groupby('month_year')['sales'].sum()
monthly_sales_df
# Out:
# month_year
# 2011-01     98898.48886
# 2011-02     91152.15698
# 2011-03    145729.36736
# 2011-04    116915.76418
# 2011-05    146747.83610
# 2011-06    215207.38022
# 2011-07    115510.41912
# 2011-08    207581.49122
# 2011-09    290214.45534
# 2011-10    199071.26404
# 2011-11    298496.53752
# 2011-12    333925.73460
# 2012-01    135780.72024
# 2012-02    100510.21698
# 2012-03    163076.77116
# 2012-04    161052.26952
# 2012-05    208364.89124
# 2012-06    256175.69842
# 2012-07    145236.78512
# 2012-08    303142.94238
# 2012-09    289389.16564
# 2012-10    252939.85020
# 2012-11    323512.41690
# 2012-12    338256.96660
# 2013-01    199185.90738
# 2013-02    167239.65040
# 2013-03    198594.03012
# 2013-04    177821.31684
# 2013-05    260498.56470
# 2013-06    396519.61190
# 2013-07    229928.95200
# 2013-08    326488.78936
# 2013-09    376619.24568
# 2013-10    293406.64288
# 2013-11    373989.36010
# 2013-12    405454.37802
# 2014-01    241268.55566
# ...

# %%
graph = px.line(data_frame=monthly_sales_df, markers=True, labels = {'value' : 'sales', 'month_year' : 'year'})
graph.show(renderer = 'iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_12.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# Insights from the visual
#
# From the lineplot we can see that, for each year the sales of first four to five months are comparatively low than the sales in the last four to five months of the year, this indicates a seasonal cycle in the sales.
#
# __

# %% [markdown]
# - <h4>Which are the top 10 products by the sales ? </h4>

# %%
prod_total_sales_df = pd.DataFrame(sales_df.groupby('product_name')['sales'].sum())

# %%
prod_total_sales_df.sort_values(by = 'sales', inplace=True, ascending= False)

# # hence top 10 products by sales are 
top_ten_df = prod_total_sales_df[: 10]
# indexing and slicing is used to get the first 10 records in the series

top_ten_df
# Out:
#                                                          sales
# product_name
# Apple Smart Phone, Full Size                        86935.7786
# Cisco Smart Phone, Full Size                        76441.5306
# Motorola Smart Phone, Full Size                     73156.3030
# Nokia Smart Phone, Full Size                        71904.5555
# Canon imageCLASS 2200 Advanced Copier               61599.8240
# Hon Executive Leather Armchair, Adjustable          58193.4841
# Office Star Executive Leather Armchair, Adjustable  50661.6840
# Harbour Creations Executive Leather Armchair, A...  50121.5160
# Samsung Smart Phone, Cordless                       48653.4600
# Nokia Smart Phone, with Caller ID                   47877.7857

# %%
graph = px.bar(data_frame=top_ten_df, x=top_ten_df.index, y=top_ten_df['sales'], color=top_ten_df.index)
graph.show(renderer = 'iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_15.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# __

# %% [markdown]
# - <h4>Which are the most selling products ? </h4>

# %%
prod_total_quant_df = pd.DataFrame(sales_df.groupby('product_name')['quantity'].sum())
prod_total_quant_df
# Out:
#                                                     quantity
# product_name
# "While you Were Out" Message Book, One Form per...         8
# #10 Gummed Flap White Envelopes, 100/Box                  11
# #10 Self-Seal White Envelopes                             10
# #10 White Business Envelopes,4 1/8 x 9 1/2                32
# #10- 4 1/8" x 9 1/2" Recycled Envelopes                   37
# ...                                                      ...
# iKross Bluetooth Portable Keyboard + Cell Phone...        24
# iOttie HLCRIO102 Car Mount                                12
# iOttie XL Car Mount                                       14
# invisibleSHIELD by ZAGG Smudge-Free Screen Prot...        29
# netTALK DUO VoIP Telephone Service                        26
#
# [3788 rows x 1 columns]

# %%
prod_total_quant_df.sort_values(by = 'quantity', ascending = False, inplace = True)
top_ten_quant_df = prod_total_quant_df[: 10]

# %%
top_ten_quant_df
# Out:
#                                        quantity
# product_name
# Staples                                     876
# Cardinal Index Tab, Clear                   337
# Eldon File Cart, Single Width               321
# Rogers File Cart, Single Width              262
# Sanford Pencil Sharpener, Water Color       259
# Stockwell Paper Clips, Assorted Sizes       253
# Avery Index Tab, Clear                      252
# Ibico Index Tab, Clear                      251
# Smead File Cart, Single Width               250
# Stanley Pencil Sharpener, Water Color       242

# %%
graph = px.bar(data_frame=top_ten_quant_df, x=top_ten_quant_df.index, y=top_ten_quant_df['quantity'], color=top_ten_quant_df.index)
graph.show(renderer = 'iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_19.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# __

# %% [markdown]
# - <h4>What is the most preferred ship mode ? </h4>

# %%
ship_mode_count_df = pd.DataFrame(sales_df['ship_mode'].value_counts())
ship_mode_count_df
# Out:
#                 ship_mode
# Standard Class      30775
# Second Class        10309
# First Class          7505
# Same Day             2701

# %%
graph = px.bar(ship_mode_count_df, labels = {'index' : 'mode', 'value' : 'count'}, color=ship_mode_count_df.index)
graph.show(renderer = 'iframe')
# Out:
# <iframe
#     scrolling="no"
#     width="100%"
#     height="545px"
#     src="iframe_figures/figure_21.html"
#     frameborder="0"
#     allowfullscreen
# ></iframe>

# %% [markdown]
# __

# %% [markdown]
# - <h4>Which are the most profitable category and sub-category ?</h4>

# %%
cat_subcat_profit = pd.DataFrame(sales_df.groupby(['category', 'sub_category'])['profit'].sum())
cat_subcat_profit.sort_values(by = ['category', 'profit'], ascending= False, inplace = True)
cat_subcat_profit
# Out:
#                                     profit
# category        sub_category
# Technology      Copiers       258567.54818
#                 Phones        216717.00580
#                 Accessories   129626.30620
#                 Machines       58867.87300
# Office Supplies Appliances    141680.58940
#                 Storage       108461.48980
#                 Binders        72449.84600
#                 Paper          59207.68270
#                 Art            57953.91090
#                 Envelopes      29601.11630
#                 Supplies       22583.26310
#                 Labels         15010.51200
#                 Fasteners      11525.42410
# Furniture       Bookcases     161924.41950
#                 Chairs        141973.79750
#                 Furnishings    46967.42550
#                 Tables        -64083.38870

# %% [markdown]
# __
